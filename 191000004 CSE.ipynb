# %% [markdown]
# Data from:
#
# https://www.kaggle.com/nehalbirla/vehicle-dataset-from-cardekho

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt, seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics
from statsmodels.regression.linear_model import OLS as ols
from sklearn.feature_extraction.text import CountVectorizer
# %matplotlib inline

# %%
car_info = pd.read_csv('C:\\Users\\ARGON\\Desktop\\PROJKT\\cardata.csv')

# %%
car_info.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
car_info.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
car_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %% [markdown]
# DATA ANALYSIS

# %%
sns.jointplot(car_info['Present_Price'], car_info['Selling_Price'])
# Out:
# C:\Users\ARGON\AppData\Roaming\Python\Python38\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.pairplot(car_info)
# ALL TYPES OF COMPARISION IN THE DATASET

# %%
sns.lmplot(x = 'Selling_Price', y = 'Present_Price', data = car_info)
# A linear model plot of Present_Price vs Selling_Price

# %% [markdown]
# The important variables are:
#
# Present_Price > Selling_Price > Car_Name > Fuel_Type > Transmission > Kms_Driven > Seller_Type > Year > Owner

# %%
# TRAINING AND TESTING

x = car_info[['Selling_Price', 'Kms_Driven', 'Year']]
y = car_info['Present_Price']

x_trn, x_tst, y_trn, y_tst = train_test_split(x, y, test_size = 0.4, random_state = 120)

# %%
lin = LinearRegression()
lin.fit(x_trn, y_trn)
# Out:
# LinearRegression()

# %%
lin.coef_
# Out:
# array([ 1.79229977e+00,  1.11039468e-07, -9.42825831e-01])

# %%
a = lin.predict(x_tst) # predictions

# %%
plt.scatter(np.array(y_tst), a) # testvalue vs predicted values

# %%
print(ols(endog = y_tst, exog = a).fit().summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:          Present_Price   R-squared (uncentered):                   0.935
# Model:                            OLS   Adj. R-squared (uncentered):              0.934
# Method:                 Least Squares   F-statistic:                              1720.
# Date:                Mon, 15 Mar 2021   Prob (F-statistic):                    5.51e-73
# Time:                        17:14:47   Log-Likelihood:                         -293.98
# No. Observations:                 121   AIC:                                      590.0
# Df Residuals:                     120   BIC:                                      592.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
one_hot = one_hot_vectorizer.fit_transform(np.array(car_info['']))
